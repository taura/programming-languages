# %% [markdown]
# # <font color="green">Loops (sum of a long array)</font>
#
# ## Problem
#
# * Write a function `sum_array_long(a, n)` that computes the sum of an `n`-element array of `long`s `a`, __in assembly__.
# * That is, translate the following C function into assembly:
# ```
# long sum_array_long(long * a, long n) {
#   long s = 0;
#   for (long i = 0; i < n; i++) { s += a[i]; }
#   return s;
# }
# ```
# * Fill in the skeleton `sum_array_long.s` (after `// ------- write your answer here -------`).
# * The checker `check_sum_array_long.c` verifies your result. If you see `OK`s and no errors, you are done.
#
# ## Hints
#
# * In assembly, loops are made of comparisons and conditional branches, just like the `if` statements you saw in the previous problems.
# * The *Observe* cells below contain `fact`, which uses a `while` loop. Compile it and locate the loop body, the increment, the comparison, and the branch back to the top.
# * In general,
# ```
# while (condition) S;
# ```
# is equivalent to
# ```
#     goto LC;
# LB: S;
# LC: c = condition;
#     if (c) goto LB;
# ```
# and the following form is also common (and correct):
# ```
#     c = condition;
#     if (!c) goto LE;
# LB: S;
#     c = condition;
#     if (c) goto LB;
# LE:
# ```
# * A `for` loop is a special case of `while`:
# ```
# for (init ; condition; increment) S;
# ```
# is equivalent to
# ```
# init;
# while (condition) { S; increment; }
# ```

# %% [markdown]
# # 1. AI Tutor
# ## 1-1. Prepare
# * Your personal AI tutor is provided for questions and feedback.
# * Execute the following cell before you use it.

# %%
import heytutor

# %% [markdown]
# ## 1-2. Examples
# * A general question
# ```
# %%hey
# What does the `ldr` instruction do in ARM64?
# ```
#
# * A hint on this specific problem
# ```
# %%hey problem_file=sum_array_long.md
# Give me a hint on this problem.
#
# {problem}
# ```
#
# * Builtin variables usable in `%%hey` cells
#   * `{file:FILENAME}` is the content of FILE
#   * `{bash[-1]}` is the output of the last `%%bash_` cell, `{bash[-2]}` the second last, etc.
#   * `{problem}` is the content of the file you specify by `%%hey problem_file=foo.md`
#   * `{answer}` is the content of the file you specify by `%%hey answer_file=foo.s`

# %% [markdown]
# # 2. Observe: compile example functions
# * Before writing your own assembly, it helps to see what the compiler generates for related example functions.
# * Running the first cell below writes `explore.c` (some small example functions related to this problem).
# * The second cell compiles it with `gcc -O3 -S` and prints the generated assembly.
# * Feel free to edit `explore.c` (change the code, add functions, change constants) and re-run the two cells to see how the assembly changes.

# %%
# %%writefile_ explore.c
# /* A loop compiled into compare + conditional branch.
#    Observe the loop body, the increment, the cmp, and the branch back to the top. */
# long fact(long n) {
#   long i = 1;
#   long p = 1;
#   while (i <= n) {
#     p = p * i;
#     i = i + 1;
#   }
#   return p;
# }

# %%
# %%bash_
# gcc -O3 -S explore.c
# cat explore.s

# %% [markdown]
# # 3. Your Answer (assembly)
# * Running the cell below writes the skeleton assembly file `sum_array_long.s`.
# * Fill in your instructions after the line `// ------- write your answer here -------`, then run the cell again to save it.

# %%
# %%writefile_ sum_array_long.s
# 	.arch armv8-a
# 	.file	"sum_array_long.c"
# 	.text
# 	.align	2
# 	.p2align 4,,11
# 	.global	sum_array_long
# 	.type	sum_array_long, %function
# sum_array_long:
# .LFB0:
# 	.cfi_startproc
# 	// ------- write your answer here -------
# 	.cfi_endproc
# .LFE0:
# 	.size	sum_array_long, .-sum_array_long
# 	.ident	"GCC: (Ubuntu 13.3.0-6ubuntu2~24.04) 13.3.0"
# 	.section	.note.GNU-stack,"",@progbits

# %% [markdown]
# # 4. Checker
# * The following C program calls your `sum_array_long` function and checks the result against a reference computed in C.

# %%
# %%writefile_ check_sum_array_long.c
# #include <assert.h>
# #include <stdio.h>
# #include <stdlib.h>
# long sum_array_long(long *, long);
#
# long sum_array_long_c(long * a, long n) {
#   long s = 0;
#   for (long i = 0; i < n; i++) {
#     s += a[i];
#   }
#   return s;
# }
#
# int main(int argc, char ** argv) {
#   long n = argc - 1;
#   long * a = (long *)malloc(sizeof(long) * n);
#   for (long i = 0; i < n; i++) {
#     a[i] = atol(argv[i + 1]);
#   }
#   long sa = sum_array_long(a, n);
#   long sa_c = sum_array_long_c(a, n);
#   if (sa == sa_c) {
#     printf("OK %ld %ld\n", sa, sa_c);
#     return 0;
#   } else {
#     printf("NG %ld %ld\n", sa, sa_c);
#     return 1;
#   }
# }

# %% [markdown]
# # 5. Compile
# * Compile your assembly together with the checker.
# * If you get an error, fix `sum_array_long.s` above and recompile.

# %%
# %%bash_
# gcc -o check_sum_array_long -O3 check_sum_array_long.c sum_array_long.s -lm

# %% [markdown]
# # 6. Run
# * If you see `OK`s and no errors, you are done.

# %%
# %%bash_
# ./check_sum_array_long 1 2 3 4 5
# ./check_sum_array_long 1 2 3 4 5 -6
# ./check_sum_array_long 1 -2 3 -4 5 -6 7

# %% [markdown]
# # 7. If things do not go well
# * If your program compiles but does not produce the correct answer, run it within a debugger (gdb).
# * Compile with `-O0 -g` first:
# ```
# gcc -o check_sum_array_long -O0 -g check_sum_array_long.c sum_array_long.s -lm
# ```
# * Then, in a terminal (SSH or Jupyter terminal):
# ```
# gdb check_sum_array_long
# (gdb) break sum_array_long
# (gdb) run ...        # give the same arguments as above
# ```
# * Step through one instruction at a time with `step`, and inspect registers with `print $x0` or `info registers`.
#
# # 8. Ask Questions or Get Feedback
# * You are encouraged to ask for feedback once you think you are done, to know if there is a better answer.

# %%
# %%hey problem_file=sum_array_long.md answer_file=sum_array_long.s
#
# Problem:
# {problem}
#
# My Answer:
# {answer}
#
# Give me a feedback to my answer.
